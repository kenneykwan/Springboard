# %% [markdown]
# ## Data Wrangling
#
# Columns Description
#
# auction_id: the unique id of the online user who has been presented the BIO. In standard terminologies this is called an impression id. The user may see the BIO questionnaire but choose not to respond. In that case both the yes and no columns are zero.
#
# experiment: which group the user belongs to - control or exposed.
#
# control: users who have been shown a dummy ad
# exposed: users who have been shown a creative, an online interactive ad, with the SmartAd brand.
# date: the date in YYYY-MM-DD format
#
# hour: the hour of the day in HH format.
#
# device_make: the name of the type of device the user has e.g. Samsung
#
# platform_os: the id of the OS the user has.
#
# browser: the name of the browser the user uses to see the BIO questionnaire.
#
# yes: 1 if the user chooses the “Yes” radio button for the BIO questionnaire.
#
# no: 1 if the user chooses the “No” radio button for the BIO questionnaire.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %%
#Load data

# %%
data = pd.read_csv('../Data/AdSmartABdata - AdSmartABdata.csv', index_col = 0)

# %%
data
# Out:
#                                      experiment        date  hour  \
# auction_id
# 0008ef63-77a7-448b-bd1e-075f42c55e39    exposed  2020-07-10     8
# 000eabc5-17ce-4137-8efe-44734d914446    exposed  2020-07-07    10
# 0016d14a-ae18-4a02-a204-6ba53b52f2ed    exposed  2020-07-05     2
# 00187412-2932-4542-a8ef-3633901c98d9    control  2020-07-03    15
# 001a7785-d3fe-4e11-a344-c8735acacc2c    control  2020-07-03    15
# ...                                         ...         ...   ...
# ffea24ec-cec1-43fb-b1d1-8f93828c2be2    exposed  2020-07-05     7
# ffea3210-2c3e-426f-a77d-0aa72e73b20f    control  2020-07-03    15
# ffeaa0f1-1d72-4ba9-afb4-314b3b00a7c7    control  2020-07-04     9
# ffeeed62-3f7c-4a6e-8ba7-95d303d40969    exposed  2020-07-05    15
# fffbb9ff-568a-41a5-a0c3-6866592f80d8    control  2020-07-10    14
#
#                                              device_make  platform_os  \
# auction_id
# 0008ef63-77a7-448b-bd1e-075f42c55e39  Generic Smartphone            6
# 000eabc5-17ce-4137-8efe-44734d914446  Generic Smartphone            6
# 0016d14a-ae18-4a02-a204-6ba53b52f2ed               E5823            6
# 00187412-2932-4542-a8ef-3633901c98d9   Samsung SM-A705FN            6
# 001a7785-d3fe-4e11-a344-c8735acacc2c  Generic Smartphone            6
# ...                                                  ...          ...
# ffea24ec-cec1-43fb-b1d1-8f93828c2be2  Generic Smartphone            6
# ffea3210-2c3e-426f-a77d-0aa72e73b20f  Generic Smartphone            6
# ffeaa0f1-1d72-4ba9-afb4-314b3b00a7c7  Generic Smartphone            6
# ffeeed62-3f7c-4a6e-8ba7-95d303d40969    Samsung SM-A515F            6
# fffbb9ff-568a-41a5-a0c3-6866592f80d8    Samsung SM-G960F            6
#
#                                                     browser  yes  no
# auction_id
# 0008ef63-77a7-448b-bd1e-075f42c55e39          Chrome Mobile    0   0
# 000eabc5-17ce-4137-8efe-44734d914446          Chrome Mobile    0   0
# 0016d14a-ae18-4a02-a204-6ba53b52f2ed  Chrome Mobile WebView    0   1
# 00187412-2932-4542-a8ef-3633901c98d9               Facebook    0   0
# 001a7785-d3fe-4e11-a344-c8735acacc2c          Chrome Mobile    0   0
# ...                                                     ...  ...  ..
# ffea24ec-cec1-43fb-b1d1-8f93828c2be2          Chrome Mobile    0   0
# ffea3210-2c3e-426f-a77d-0aa72e73b20f          Chrome Mobile    0   0
# ffeaa0f1-1d72-4ba9-afb4-314b3b00a7c7          Chrome Mobile    0   0
# ffeeed62-3f7c-4a6e-8ba7-95d303d40969       Samsung Internet    0   0
# fffbb9ff-568a-41a5-a0c3-6866592f80d8               Facebook    0   0
#
# [8077 rows x 8 columns]

# %%
#checking if index is unique for all rows
data.index.nunique()
# Out:
# 8077

# %%
#checking for null values
data.isnull().sum()
# Out:
# experiment     0
# date           0
# hour           0
# device_make    0
# platform_os    0
# browser        0
# yes            0
# no             0
# dtype: int64

# %%
#percentage of sample given control ad or experimental advertisment
data['experiment'].value_counts()/8077 * 100
# Out:
# control    50.402377
# exposed    49.597623
# Name: experiment, dtype: float64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8077 entries, 0008ef63-77a7-448b-bd1e-075f42c55e39 to fffbb9ff-568a-41a5-a0c3-6866592f80d8
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   experiment   8077 non-null   object
#  1   date         8077 non-null   object
#  2   hour         8077 non-null   int64
#  3   device_make  8077 non-null   object
#  4   platform_os  8077 non-null   int64
#  5   browser      8077 non-null   object
#  6   yes          8077 non-null   int64
#  7   no           8077 non-null   int64
# dtypes: int64(4), object(4)
# memory usage: 567.9+ KB

# %%
data['date'] = pd.to_datetime(data['date'])

# %%
#combine yes and no column
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8077 entries, 0008ef63-77a7-448b-bd1e-075f42c55e39 to fffbb9ff-568a-41a5-a0c3-6866592f80d8
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   experiment   8077 non-null   object
#  1   date         8077 non-null   datetime64[ns]
#  2   hour         8077 non-null   int64
#  3   device_make  8077 non-null   object
#  4   platform_os  8077 non-null   int64
#  5   browser      8077 non-null   object
#  6   yes          8077 non-null   int64
#  7   no           8077 non-null   int64
# dtypes: datetime64[ns](1), int64(4), object(3)
# memory usage: 567.9+ KB

# %%
#combine yes and no column
yes_no = []
no_response=[]
for x, y in zip(data['yes'], data['no']):
    if(x ==1):
        yes_no.append(1)
    if(x == 0):
        yes_no.append(0)
    if(x == 0) & (y == 0):
        no_response.append(1)
    if(x == 1) | (y == 1):
        no_response.append(0)
data['success'] = yes_no
data['no_response'] = no_response

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8077 entries, 0008ef63-77a7-448b-bd1e-075f42c55e39 to fffbb9ff-568a-41a5-a0c3-6866592f80d8
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   experiment   8077 non-null   object
#  1   date         8077 non-null   datetime64[ns]
#  2   hour         8077 non-null   int64
#  3   device_make  8077 non-null   object
#  4   platform_os  8077 non-null   int64
#  5   browser      8077 non-null   object
#  6   yes          8077 non-null   int64
#  7   no           8077 non-null   int64
#  8   success      8077 non-null   int64
#  9   no_response  8077 non-null   int64
# dtypes: datetime64[ns](1), int64(6), object(3)
# memory usage: 694.1+ KB

# %%
data['success'].head(30)
# Out:
# auction_id
# 0008ef63-77a7-448b-bd1e-075f42c55e39    0
# 000eabc5-17ce-4137-8efe-44734d914446    0
# 0016d14a-ae18-4a02-a204-6ba53b52f2ed    0
# 00187412-2932-4542-a8ef-3633901c98d9    0
# 001a7785-d3fe-4e11-a344-c8735acacc2c    0
# 0027ce48-d3c6-4935-bb12-dfb5d5627857    0
# 002e308b-1a07-49d6-8560-0fbcdcd71e4b    0
# 00393fb9-ca32-40c0-bfcb-1bd83f319820    0
# 004940f5-c642-417a-8fd2-c8e5d989f358    0
# 004c4cc9-f2ca-4df7-adc9-3d0c3c4f0342    0
# 004c8a83-1c0f-4a4a-ba9e-bc89e8c0c0c1    0
# 0051dd9b-03b6-4579-b09a-0107b2a3a13e    0
# 0057654c-4781-4ddc-af0f-c584f776a6c8    0
# 006b9c6e-5f5d-4385-a811-ff20a24b30ac    0
# 0073f9a6-0856-44b4-870d-8e525878ad29    0
# 0084b196-3752-4fb0-9892-852d28db4c2a    0
# 008aafdf-deef-4482-8fec-d98e3da054da    1
# 009921b9-85e0-4ef4-97bb-056b4d4eb37c    0
# 009d83e9-7337-412d-82e2-994f2d13a4ef    0
# 009f8ffc-3188-433d-8946-965c40444587    0
# 00a1384a-5118-4d1b-925b-6cdada50318d    0
# 00b0dd5a-6c44-4a2e-82bd-a4dddf826a9f    0
# 00b6f2ed-a497-4269-a78f-77d4f26d85cd    0
# 00b6fadb-10bd-49e3-a778-290da82f7a8d    1
# 00be1b54-f635-4def-be18-f9322b62a88e    0
# 00d22463-2d1f-44de-8d67-11d6c6b96a00    0
# 00e4f247-b54b-4f95-a000-ec4645d5a692    0
# 00ebf4a8-060f-4b99-93ac-c62724399483    0
# 00ece802-4a85-43d3-8cf5-ebe94f83d632    0
# 00ed819f-8486-43fe-aba7-b264fba62e1d    0
# Name: success, dtype: int64

# %%
data.head(30)
# Out:
#                                      experiment       date  hour  \
# auction_id
# 0008ef63-77a7-448b-bd1e-075f42c55e39    exposed 2020-07-10     8
# 000eabc5-17ce-4137-8efe-44734d914446    exposed 2020-07-07    10
# 0016d14a-ae18-4a02-a204-6ba53b52f2ed    exposed 2020-07-05     2
# 00187412-2932-4542-a8ef-3633901c98d9    control 2020-07-03    15
# 001a7785-d3fe-4e11-a344-c8735acacc2c    control 2020-07-03    15
# 0027ce48-d3c6-4935-bb12-dfb5d5627857    control 2020-07-03    15
# 002e308b-1a07-49d6-8560-0fbcdcd71e4b    control 2020-07-03    15
# 00393fb9-ca32-40c0-bfcb-1bd83f319820    control 2020-07-09     5
# 004940f5-c642-417a-8fd2-c8e5d989f358    exposed 2020-07-04     0
# 004c4cc9-f2ca-4df7-adc9-3d0c3c4f0342    control 2020-07-05    14
# 004c8a83-1c0f-4a4a-ba9e-bc89e8c0c0c1    control 2020-07-10    13
# 0051dd9b-03b6-4579-b09a-0107b2a3a13e    control 2020-07-09     6
# 0057654c-4781-4ddc-af0f-c584f776a6c8    control 2020-07-05     8
# 006b9c6e-5f5d-4385-a811-ff20a24b30ac    exposed 2020-07-06     8
# 0073f9a6-0856-44b4-870d-8e525878ad29    exposed 2020-07-04    15
# 0084b196-3752-4fb0-9892-852d28db4c2a    exposed 2020-07-07    16
# 008aafdf-deef-4482-8fec-d98e3da054da    exposed 2020-07-04    16
# 009921b9-85e0-4ef4-97bb-056b4d4eb37c    control 2020-07-04     7
# 009d83e9-7337-412d-82e2-994f2d13a4ef    exposed 2020-07-10     6
# 009f8ffc-3188-433d-8946-965c40444587    control 2020-07-03    15
# 00a1384a-5118-4d1b-925b-6cdada50318d    exposed 2020-07-06     8
# 00b0dd5a-6c44-4a2e-82bd-a4dddf826a9f    control 2020-07-08    20
# 00b6f2ed-a497-4269-a78f-77d4f26d85cd    control 2020-07-03    15
# 00b6fadb-10bd-49e3-a778-290da82f7a8d    control 2020-07-08     4
# 00be1b54-f635-4def-be18-f9322b62a88e    exposed 2020-07-09    17
# 00d22463-2d1f-44de-8d67-11d6c6b96a00    exposed 2020-07-03     1
# 00e4f247-b54b-4f95-a000-ec4645d5a692    control 2020-07-03    15
# 00ebf4a8-060f-4b99-93ac-c62724399483    control 2020-07-03    15
# 00ece802-4a85-43d3-8cf5-ebe94f83d632    control 2020-07-03    15
# 00ed819f-8486-43fe-aba7-b264fba62e1d    control 2020-07-03    15
#
#                                              device_make  platform_os  \
# auction_id
# 0008ef63-77a7-448b-bd1e-075f42c55e39  Generic Smartphone            6
# 000eabc5-17ce-4137-8efe-44734d914446  Generic Smartphone            6
# 0016d14a-ae18-4a02-a204-6ba53b52f2ed               E5823            6
# 00187412-2932-4542-a8ef-3633901c98d9   Samsung SM-A705FN            6
# 001a7785-d3fe-4e11-a344-c8735acacc2c  Generic Smartphone            6
# 0027ce48-d3c6-4935-bb12-dfb5d5627857    Samsung SM-G960F            6
# 002e308b-1a07-49d6-8560-0fbcdcd71e4b  Generic Smartphone            6
# 00393fb9-ca32-40c0-bfcb-1bd83f319820    Samsung SM-G973F            6
# 004940f5-c642-417a-8fd2-c8e5d989f358  Generic Smartphone            6
# 004c4cc9-f2ca-4df7-adc9-3d0c3c4f0342  Generic Smartphone            6
# 004c8a83-1c0f-4a4a-ba9e-bc89e8c0c0c1              iPhone            5
# 0051dd9b-03b6-4579-b09a-0107b2a3a13e    Samsung SM-G935F            6
# 0057654c-4781-4ddc-af0f-c584f776a6c8  Generic Smartphone            6
# 006b9c6e-5f5d-4385-a811-ff20a24b30ac    Samsung SM-G973F            6
# 0073f9a6-0856-44b4-870d-8e525878ad29    Samsung SM-G960F            6
# 0084b196-3752-4fb0-9892-852d28db4c2a             HTC One            6
# 008aafdf-deef-4482-8fec-d98e3da054da  Generic Smartphone            6
# 009921b9-85e0-4ef4-97bb-056b4d4eb37c  Generic Smartphone            6
# 009d83e9-7337-412d-82e2-994f2d13a4ef  Generic Smartphone            6
# 009f8ffc-3188-433d-8946-965c40444587  Generic Smartphone            6
# 00a1384a-5118-4d1b-925b-6cdada50318d  Generic Smartphone            6
# 00b0dd5a-6c44-4a2e-82bd-a4dddf826a9f  Generic Smartphone            6
# 00b6f2ed-a497-4269-a78f-77d4f26d85cd               LG-$2            6
# 00b6fadb-10bd-49e3-a778-290da82f7a8d    Samsung SM-A202F            6
# 00be1b54-f635-4def-be18-f9322b62a88e  Generic Smartphone            6
# 00d22463-2d1f-44de-8d67-11d6c6b96a00              iPhone            5
# 00e4f247-b54b-4f95-a000-ec4645d5a692              iPhone            5
# 00ebf4a8-060f-4b99-93ac-c62724399483  Generic Smartphone            6
# 00ece802-4a85-43d3-8cf5-ebe94f83d632  Generic Smartphone            6
# 00ed819f-8486-43fe-aba7-b264fba62e1d  Generic Smartphone            6
#
#                                                     browser  yes  no  success  \
# auction_id
# 0008ef63-77a7-448b-bd1e-075f42c55e39          Chrome Mobile    0   0        0
# 000eabc5-17ce-4137-8efe-44734d914446          Chrome Mobile    0   0        0
# 0016d14a-ae18-4a02-a204-6ba53b52f2ed  Chrome Mobile WebView    0   1        0
# 00187412-2932-4542-a8ef-3633901c98d9               Facebook    0   0        0
# 001a7785-d3fe-4e11-a344-c8735acacc2c          Chrome Mobile    0   0        0
# 0027ce48-d3c6-4935-bb12-dfb5d5627857               Facebook    0   0        0
# 002e308b-1a07-49d6-8560-0fbcdcd71e4b          Chrome Mobile    0   0        0
# 00393fb9-ca32-40c0-bfcb-1bd83f319820               Facebook    0   0        0
# 004940f5-c642-417a-8fd2-c8e5d989f358  Chrome Mobile WebView    0   0        0
# 004c4cc9-f2ca-4df7-adc9-3d0c3c4f0342          Chrome Mobile    0   0        0
# 004c8a83-1c0f-4a4a-ba9e-bc89e8c0c0c1          Mobile Safari    0   0        0
# 0051dd9b-03b6-4579-b09a-0107b2a3a13e  Chrome Mobile WebView    0   0        0
# 0057654c-4781-4ddc-af0f-c584f776a6c8          Chrome Mobile    0   0        0
# 006b9c6e-5f5d-4385-a811-ff20a24b30ac  Chrome Mobile WebView    0   0        0
# 0073f9a6-0856-44b4-870d-8e525878ad29  Chrome Mobile WebView    0   0        0
# 0084b196-3752-4fb0-9892-852d28db4c2a          Chrome Mobile    0   0        0
# 008aafdf-deef-4482-8fec-d98e3da054da          Chrome Mobile    1   0        1
# 009921b9-85e0-4ef4-97bb-056b4d4eb37c          Chrome Mobile    0   0        0
# 009d83e9-7337-412d-82e2-994f2d13a4ef          Chrome Mobile    0   0        0
# 009f8ffc-3188-433d-8946-965c40444587          Chrome Mobile    0   0        0
# 00a1384a-5118-4d1b-925b-6cdada50318d          Chrome Mobile    0   1        0
# 00b0dd5a-6c44-4a2e-82bd-a4dddf826a9f          Chrome Mobile    0   0        0
# 00b6f2ed-a497-4269-a78f-77d4f26d85cd          Chrome Mobile    0   0        0
# 00b6fadb-10bd-49e3-a778-290da82f7a8d               Facebook    1   0        1
# 00be1b54-f635-4def-be18-f9322b62a88e          Chrome Mobile    0   0        0
# 00d22463-2d1f-44de-8d67-11d6c6b96a00      Chrome Mobile iOS    0   0        0
# 00e4f247-b54b-4f95-a000-ec4645d5a692          Mobile Safari    0   0        0
# 00ebf4a8-060f-4b99-93ac-c62724399483          Chrome Mobile    0   1        0
# 00ece802-4a85-43d3-8cf5-ebe94f83d632          Chrome Mobile    0   0        0
# 00ed819f-8486-43fe-aba7-b264fba62e1d          Chrome Mobile    0   0        0
#
#                                       no_response
# auction_id
# 0008ef63-77a7-448b-bd1e-075f42c55e39            1
# 000eabc5-17ce-4137-8efe-44734d914446            1
# 0016d14a-ae18-4a02-a204-6ba53b52f2ed            0
# 00187412-2932-4542-a8ef-3633901c98d9            1
# 001a7785-d3fe-4e11-a344-c8735acacc2c            1
# 0027ce48-d3c6-4935-bb12-dfb5d5627857            1
# 002e308b-1a07-49d6-8560-0fbcdcd71e4b            1
# 00393fb9-ca32-40c0-bfcb-1bd83f319820            1
# 004940f5-c642-417a-8fd2-c8e5d989f358            1
# 004c4cc9-f2ca-4df7-adc9-3d0c3c4f0342            1
# 004c8a83-1c0f-4a4a-ba9e-bc89e8c0c0c1            1
# 0051dd9b-03b6-4579-b09a-0107b2a3a13e            1
# 0057654c-4781-4ddc-af0f-c584f776a6c8            1
# 006b9c6e-5f5d-4385-a811-ff20a24b30ac            1
# 0073f9a6-0856-44b4-870d-8e525878ad29            1
# 0084b196-3752-4fb0-9892-852d28db4c2a            1
# 008aafdf-deef-4482-8fec-d98e3da054da            0
# 009921b9-85e0-4ef4-97bb-056b4d4eb37c            1
# 009d83e9-7337-412d-82e2-994f2d13a4ef            1
# 009f8ffc-3188-433d-8946-965c40444587            1
# 00a1384a-5118-4d1b-925b-6cdada50318d            0
# 00b0dd5a-6c44-4a2e-82bd-a4dddf826a9f            1
# 00b6f2ed-a497-4269-a78f-77d4f26d85cd            1
# 00b6fadb-10bd-49e3-a778-290da82f7a8d            0
# 00be1b54-f635-4def-be18-f9322b62a88e            1
# 00d22463-2d1f-44de-8d67-11d6c6b96a00            1
# 00e4f247-b54b-4f95-a000-ec4645d5a692            1
# 00ebf4a8-060f-4b99-93ac-c62724399483            0
# 00ece802-4a85-43d3-8cf5-ebe94f83d632            1
# 00ed819f-8486-43fe-aba7-b264fba62e1d            1

# %%
data = data.drop(columns = ['yes','no'], axis = 1)

# %%
data
# Out:
#                                      experiment       date  hour  \
# auction_id
# 0008ef63-77a7-448b-bd1e-075f42c55e39    exposed 2020-07-10     8
# 000eabc5-17ce-4137-8efe-44734d914446    exposed 2020-07-07    10
# 0016d14a-ae18-4a02-a204-6ba53b52f2ed    exposed 2020-07-05     2
# 00187412-2932-4542-a8ef-3633901c98d9    control 2020-07-03    15
# 001a7785-d3fe-4e11-a344-c8735acacc2c    control 2020-07-03    15
# ...                                         ...        ...   ...
# ffea24ec-cec1-43fb-b1d1-8f93828c2be2    exposed 2020-07-05     7
# ffea3210-2c3e-426f-a77d-0aa72e73b20f    control 2020-07-03    15
# ffeaa0f1-1d72-4ba9-afb4-314b3b00a7c7    control 2020-07-04     9
# ffeeed62-3f7c-4a6e-8ba7-95d303d40969    exposed 2020-07-05    15
# fffbb9ff-568a-41a5-a0c3-6866592f80d8    control 2020-07-10    14
#
#                                              device_make  platform_os  \
# auction_id
# 0008ef63-77a7-448b-bd1e-075f42c55e39  Generic Smartphone            6
# 000eabc5-17ce-4137-8efe-44734d914446  Generic Smartphone            6
# 0016d14a-ae18-4a02-a204-6ba53b52f2ed               E5823            6
# 00187412-2932-4542-a8ef-3633901c98d9   Samsung SM-A705FN            6
# 001a7785-d3fe-4e11-a344-c8735acacc2c  Generic Smartphone            6
# ...                                                  ...          ...
# ffea24ec-cec1-43fb-b1d1-8f93828c2be2  Generic Smartphone            6
# ffea3210-2c3e-426f-a77d-0aa72e73b20f  Generic Smartphone            6
# ffeaa0f1-1d72-4ba9-afb4-314b3b00a7c7  Generic Smartphone            6
# ffeeed62-3f7c-4a6e-8ba7-95d303d40969    Samsung SM-A515F            6
# fffbb9ff-568a-41a5-a0c3-6866592f80d8    Samsung SM-G960F            6
#
#                                                     browser  success  \
# auction_id
# 0008ef63-77a7-448b-bd1e-075f42c55e39          Chrome Mobile        0
# 000eabc5-17ce-4137-8efe-44734d914446          Chrome Mobile        0
# 0016d14a-ae18-4a02-a204-6ba53b52f2ed  Chrome Mobile WebView        0
# 00187412-2932-4542-a8ef-3633901c98d9               Facebook        0
# 001a7785-d3fe-4e11-a344-c8735acacc2c          Chrome Mobile        0
# ...                                                     ...      ...
# ffea24ec-cec1-43fb-b1d1-8f93828c2be2          Chrome Mobile        0
# ffea3210-2c3e-426f-a77d-0aa72e73b20f          Chrome Mobile        0
# ffeaa0f1-1d72-4ba9-afb4-314b3b00a7c7          Chrome Mobile        0
# ffeeed62-3f7c-4a6e-8ba7-95d303d40969       Samsung Internet        0
# fffbb9ff-568a-41a5-a0c3-6866592f80d8               Facebook        0
#
#                                       no_response
# auction_id
# 0008ef63-77a7-448b-bd1e-075f42c55e39            1
# 000eabc5-17ce-4137-8efe-44734d914446            1
# 0016d14a-ae18-4a02-a204-6ba53b52f2ed            0
# 00187412-2932-4542-a8ef-3633901c98d9            1
# 001a7785-d3fe-4e11-a344-c8735acacc2c            1
# ...                                           ...
# ffea24ec-cec1-43fb-b1d1-8f93828c2be2            1
# ffea3210-2c3e-426f-a77d-0aa72e73b20f            1
# ffeaa0f1-1d72-4ba9-afb4-314b3b00a7c7            1
# ffeeed62-3f7c-4a6e-8ba7-95d303d40969            1
# fffbb9ff-568a-41a5-a0c3-6866592f80d8            1
#
# [8077 rows x 8 columns]

# %%
data.to_csv('../Data/abtesting_cleaned.csv')
